# %%
import pandas as pd
import zipfile
import seaborn as sns
import numpy as np
import pickle

# %%
data_path="../data/data_accuracy"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path="/content/drive/MyDrive/M5_forecasting/data/data_accuracy"

# %%
grouped_data = pd.read_csv(data_path+"/grouped_data.csv")

# %%
grouped_data.shape
# Out:
# (42839, 1916)

# %%
def timeplot(,id):

# %%
grouped_data
# Out:
#        Unnamed: 0            id            idmap  ...  d_1911  d_1912  d_1913
# 0               0   FOODS_1_001          item_id  ...       2      16       6
# 1               1   FOODS_1_002          item_id  ...       3       3       1
# 2               2   FOODS_1_003          item_id  ...       3      11       5
# 3               3   FOODS_1_004          item_id  ...       0       0       0
# 4               4   FOODS_1_005          item_id  ...      15      38       9
# ...           ...           ...              ...  ...     ...     ...     ...
# 42834       48939    HOBBIES|TX  cat_id|state_id  ...    1056    1222    1266
# 42835       48940    HOBBIES|WI  cat_id|state_id  ...    1014    1198    1060
# 42836       48941  HOUSEHOLD|CA  cat_id|state_id  ...    4089    5622    6024
# 42837       48942  HOUSEHOLD|TX  cat_id|state_id  ...    2720    3195    3251
# 42838       48943  HOUSEHOLD|WI  cat_id|state_id  ...    2919    3431    3183
#
# [42839 rows x 1916 columns]

# %%
grouped_data[grouped_data.id=="overall"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id, idmap, d_1, d_2, d_3, d_4, d_5, d_6, d_7, d_8, d_9, d_10, d_11, d_12, d_13, d_14, d_15, d_16, d_17, d_18, d_19, d_20, d_21, d_22, d_23, d_24, d_25, d_26, d_27, d_28, d_29, d_30, d_31, d_32, d_33, d_34, d_35, d_36, d_37, d_38, d_39, d_40, d_41, d_42, d_43, d_44, d_45, d_46, d_47, d_48, d_49, d_50, d_51, d_52, d_53, d_54, d_55, d_56, d_57, d_58, d_59, d_60, d_61, d_62, d_63, d_64, d_65, d_66, d_67, d_68, d_69, d_70, d_71, d_72, d_73, d_74, d_75, d_76, d_77, d_78, d_79, d_80, d_81, d_82, d_83, d_84, d_85, d_86, d_87, d_88, d_89, d_90, d_91, d_92, d_93, d_94, d_95, d_96, d_97, ...]
# Index: []
#
# [0 rows x 1916 columns]
